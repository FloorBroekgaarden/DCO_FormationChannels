# %%
#Needed in general
import sys

#Quick fudge to make import from ../Scripts work
sys.path.append('../../../common_code')
from PostProcessingScripts import * 
# from ClassFormationChannels_5mainchannels import * 

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))



colors = ['#1f77b4', '#ff7f0e']
colors_lighter = [adjust_lightness(color=colors[0], amount=2.2),adjust_lightness(color=colors[1], amount=1.7)]

from formation_channels import * 
# Generate a distribution and draw 2**6 data points

from KDEpy import FFTKDE
# Out:
# obtain index of the SFRD models that we want to highlight
# /var/folders/lc/vg4hc2nn2pn05y4lw3h5wmpm0000gn/T/ipykernel_98912/75625263.py:9: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 20
#      17 from formation_channels import *
#      18 # Generate a distribution and draw 2**6 data points
# ---> 20 from KDEpy import FFTKDE
#
# ModuleNotFoundError: No module named 'KDEpy'

# %%
pip install astropy

# %%
pip install scipy

# %%
pip install KDEpy
# Out:
# Collecting KDEpy
#   Using cached KDEpy-1.0.2.tar.gz (136 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.2 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from KDEpy) (1.24.2)
# Requirement already satisfied: scipy>=1.0.1 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from KDEpy) (1.10.1)
# Requirement already satisfied: matplotlib>=2.2.0 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from KDEpy) (3.7.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from matplotlib>=2.2.0->KDEpy) (4.38.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from matplotlib>=2.2.0->KDEpy) (5.12.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from matplotlib>=2.2.0->KDEpy) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from matplotlib>=2.2.0->KDEpy) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from matplotlib>=2.2.0->KDEpy) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from matplotlib>=2.2.0->KDEpy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from matplotlib>=2.2.0->KDEpy) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from matplotlib>=2.2.0->KDEpy) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from matplotlib>=2.2.0->KDEpy) (9.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.2.0->KDEpy) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.0->KDEpy) (1.16.0)
# Building wheels for collected packages: KDEpy
#   Building wheel for KDEpy (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [212 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-39
#       creating build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/binning.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/kernel_funcs.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/FFTKDE.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/TreeKDE.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/NaiveKDE.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/BaseKDE.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/bw_selection.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/utils.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       running build_ext
#       skipping 'KDEpy/cutils.c' Cython extension (up-to-date)
#       building 'cutils' extension
#       creating build/temp.macosx-11.1-arm64-cpython-39
#       creating build/temp.macosx-11.1-arm64-cpython-39/KDEpy
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include -arch arm64 -I/Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include -fPIC -O2 -isystem /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include -arch arm64 -I/Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages/numpy/core/include -I/Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9 -c KDEpy/cutils.c -o build/temp.macosx-11.1-arm64-cpython-39/KDEpy/cutils.o
#       KDEpy/cutils.c:18644:26: error: no member named 'tp_print' in 'struct _typeobject'
#         __pyx_type___pyx_array.tp_print = 0;
#         ~~~~~~~~~~~~~~~~~~~~~~ ^
#       KDEpy/cutils.c:18649:32: error: no member named 'tp_print' in 'struct _typeobject'
#         __pyx_type___pyx_MemviewEnum.tp_print = 0;
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^
#       KDEpy/cutils.c:18664:31: error: no member named 'tp_print' in 'struct _typeobject'
#         __pyx_type___pyx_memoryview.tp_print = 0;
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^
#       KDEpy/cutils.c:18677:36: error: no member named 'tp_print' in 'struct _typeobject'
#         __pyx_type___pyx_memoryviewslice.tp_print = 0;
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^
#       KDEpy/cutils.c:19320:22: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                            ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#             PyUnicode_WSTR_LENGTH(op) :                    \
#             ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:22: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                            ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#             ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                    ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:22: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                            ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#              PyUnicode_WSTR_LENGTH(op)))
#              ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:52: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                          ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#             PyUnicode_WSTR_LENGTH(op) :                    \
#             ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:52: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                          ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#             ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                    ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:52: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                          ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#              PyUnicode_WSTR_LENGTH(op)))
#              ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:26: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#             PyUnicode_WSTR_LENGTH(op) :                    \
#             ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:26: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#             ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                    ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:26: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#              PyUnicode_WSTR_LENGTH(op)))
#              ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:59: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                 ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#             PyUnicode_WSTR_LENGTH(op) :                    \
#             ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:59: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                 ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#             ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                    ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:59: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                 ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#              PyUnicode_WSTR_LENGTH(op)))
#              ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:20396:16: warning: 'PyUnicode_FromUnicode' is deprecated [-Wdeprecated-declarations]
#               return PyUnicode_FromUnicode(NULL, 0);
#                      ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:551:1: note: 'PyUnicode_FromUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       13 warnings and 4 errors generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for KDEpy
#   Running setup.py clean for KDEpy
# Failed to build KDEpy
# Installing collected packages: KDEpy
#   Running setup.py install for KDEpy ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for KDEpy did not run successfully.
#   │ exit code: 1
#   ╰─> [214 lines of output]
#       running install
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-39
#       creating build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/binning.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/kernel_funcs.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/__init__.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/FFTKDE.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/TreeKDE.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/NaiveKDE.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/BaseKDE.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/bw_selection.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       copying KDEpy/utils.py -> build/lib.macosx-11.1-arm64-cpython-39/KDEpy
#       running build_ext
#       skipping 'KDEpy/cutils.c' Cython extension (up-to-date)
#       building 'cutils' extension
#       creating build/temp.macosx-11.1-arm64-cpython-39
#       creating build/temp.macosx-11.1-arm64-cpython-39/KDEpy
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include -arch arm64 -I/Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include -fPIC -O2 -isystem /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include -arch arm64 -I/Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/lib/python3.9/site-packages/numpy/core/include -I/Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9 -c KDEpy/cutils.c -o build/temp.macosx-11.1-arm64-cpython-39/KDEpy/cutils.o
#       KDEpy/cutils.c:18644:26: error: no member named 'tp_print' in 'struct _typeobject'
#         __pyx_type___pyx_array.tp_print = 0;
#         ~~~~~~~~~~~~~~~~~~~~~~ ^
#       KDEpy/cutils.c:18649:32: error: no member named 'tp_print' in 'struct _typeobject'
#         __pyx_type___pyx_MemviewEnum.tp_print = 0;
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^
#       KDEpy/cutils.c:18664:31: error: no member named 'tp_print' in 'struct _typeobject'
#         __pyx_type___pyx_memoryview.tp_print = 0;
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^
#       KDEpy/cutils.c:18677:36: error: no member named 'tp_print' in 'struct _typeobject'
#         __pyx_type___pyx_memoryviewslice.tp_print = 0;
#         ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^
#       KDEpy/cutils.c:19320:22: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                            ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#             PyUnicode_WSTR_LENGTH(op) :                    \
#             ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:22: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                            ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#             ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                    ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:22: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                            ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#              PyUnicode_WSTR_LENGTH(op)))
#              ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:52: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                          ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#             PyUnicode_WSTR_LENGTH(op) :                    \
#             ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:52: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                          ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#             ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                    ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19320:52: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                           (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                          ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#              PyUnicode_WSTR_LENGTH(op)))
#              ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:26: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#             PyUnicode_WSTR_LENGTH(op) :                    \
#             ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:26: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#             ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                    ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:26: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#              PyUnicode_WSTR_LENGTH(op)))
#              ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:59: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                 ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:261:7: note: expanded from macro 'PyUnicode_GET_SIZE'
#             PyUnicode_WSTR_LENGTH(op) :                    \
#             ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:59: warning: 'PyUnicode_AsUnicode' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                 ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:262:14: note: expanded from macro 'PyUnicode_GET_SIZE'
#             ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                    ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:580:1: note: 'PyUnicode_AsUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:19336:59: warning: '_PyUnicode_get_wstr_length' is deprecated [-Wdeprecated-declarations]
#                               (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                                                                 ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:264:8: note: expanded from macro 'PyUnicode_GET_SIZE'
#              PyUnicode_WSTR_LENGTH(op)))
#              ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:451:35: note: expanded from macro 'PyUnicode_WSTR_LENGTH'
#       #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                                         ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:445:1: note: '_PyUnicode_get_wstr_length' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3)
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       KDEpy/cutils.c:20396:16: warning: 'PyUnicode_FromUnicode' is deprecated [-Wdeprecated-declarations]
#               return PyUnicode_FromUnicode(NULL, 0);
#                      ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/cpython/unicodeobject.h:551:1: note: 'PyUnicode_FromUnicode' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#       ^
#       /Users/floorbroekgaarden/miniforge3/envs/ipykernel_py39/include/python3.9/pyport.h:508:54: note: expanded from macro 'Py_DEPRECATED'
#       #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                            ^
#       13 warnings and 4 errors generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> KDEpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# Note: you may need to restart the kernel to use updated packages.
